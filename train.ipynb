# %%
# This file is a modified version of the original:
# https://github.com/LIHANG-HONG/birdclef2023-2nd-place-solution/blob/main/train.py

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import argparse
import importlib
from modules.preprocess import preprocess,prepare_cfg
from modules.dataset import get_train_dataloader
from modules.model import load_model
import pytorch_lightning as pl
from pytorch_lightning.loggers import CSVLogger, WandbLogger
from pytorch_lightning.callbacks import ModelCheckpoint, BackboneFinetuning, EarlyStopping, TQDMProgressBar
import torch
import os
import gc
import json

# %%
# import graphviz
# graphviz.set_jupyter_format('png')
# from torchview import draw_graph

# %%
def make_parser():
    parser = argparse.ArgumentParser(description='BirdCLEF2023')
    # _ce denotes => cross-entropy.
    # _bce denotes => binary cross-entropy.
    parser.add_argument('--stage', default="pretrain_ce", choices=["pretrain_ce","pretrain_bce","train_ce","train_bce","finetune"])
    # sed => sound event detection
    parser.add_argument('--model_name', default="sed_v2s", choices=["sed_v2s",'sed_b3ns','sed_seresnext26t','cnn_v2s','cnn_resnet34d','cnn_b3ns','cnn_b0ns'])
    parser.add_argument('--use_pseudo', action='store_true')
    return parser

# %%
def main():
    parser = make_parser()
    args, unknown = parser.parse_known_args()
    stage = args.stage
    model_name = args.model_name
    use_pseudo = args.use_pseudo
    cfg = importlib.import_module(f'configs.{model_name}').basic_cfg
    cfg = prepare_cfg(cfg,stage)
    os.environ['WANDB_API_KEY'] = cfg.WANDB_API_KEY
    
    pl.seed_everything(cfg.seed[stage], workers=True)

    df_train, df_valid, df_label_train, df_label_valid, sample_weight, transforms = preprocess(cfg,stage)
    # df_valid and df_label_valid => empty dataframe
        
    pseudo = None

    # use_pseudo => False
    if use_pseudo:
        # =========================================================
        with open('/content/birdclef2023-2nd-place-solution/inputs/pseudo_label/pseudo.json') as f:
            pseudo = json.loads(f.read())

        with open('/content/birdclef2023-2nd-place-solution/inputs/hand_label/hand_label.json') as f:
            hand_label = json.loads(f.read())

        for version in hand_label['pred'].keys():
            for filename in hand_label['pred'][version].keys():
                for label in hand_label['pred'][version][filename].keys():
                    for second in hand_label['pred'][version][filename][label].keys():
                        for i in range(len(pseudo['subset1']['pseudo'])):
                            if second in pseudo['subset1']['pseudo'][i]['pred'][version][filename][label].keys():
                                pseudo['subset1']['pseudo'][i]['pred'][version][filename][label][second] = hand_label['pred'][version][filename][label][second]
        # =========================================================

    dl_train, dl_val, ds_train, ds_val = get_train_dataloader(
        df_train, # my_ [0:16]
        df_valid, # my_ [0:16]
        df_label_train, # my_ [0:16]
        df_label_valid, # my_ [0:16]
        sample_weight, # my_ [0:16]
        cfg,
        pseudo,
        transforms
    )

    #logger = WandbLogger(project='BirdClef-2023', name=f'{model_name}_{stage}') # disabled wandb
    logger = CSVLogger("logs", name=f'{model_name}_{stage}')
    
    checkpoint_callback = ModelCheckpoint(
        monitor=None, # 'val_loss', None
        dirpath= cfg.output_path[stage],
        save_top_k=0,
        save_last= True,
        save_weights_only=True,
        #filename= './ckpt_epoch_{epoch}_val_loss_{val_loss:.2f}',
        #filename ='./ckpt_{epoch}_{val_loss}',
        verbose= True,
        every_n_epochs=1,
        mode='min'
    )
    callbacks_to_use = [checkpoint_callback]        
    model = load_model(cfg,stage,train=True)
    
    trainer = pl.Trainer(
        devices=1,
        val_check_interval=1.0,
        deterministic=None,
        max_epochs=cfg.epochs[stage],
        logger=logger,
        callbacks=callbacks_to_use,
        precision=cfg.PRECISION, accelerator="auto",
    )

    print("Running trainer.fit")
        
    trainer.fit(model, train_dataloaders = dl_train, val_dataloaders = dl_val)

    _ = gc.collect()
    torch.cuda.empty_cache()
    return

# %%
if __name__=='__main__':
    main()
# Out:
# Global seed set to 20231121
# ===========================================================
# warning: missing audio files in ./inputs/train_audios
# warning: only audios available will be used for training
# ===========================================================
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# You are using a CUDA device ('NVIDIA GeForce RTX 3050') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                | Type             | Params
# ----------------------------------------------------------
# 0  | loss_function       | CrossEntropyLoss | 0
# 1  | mixup               | Mixup            | 0
# 2  | mixup2              | Mixup2           | 0
# 3  | audio_transforms    | Compose          | 0
# 4  | time_mask_transform | TimeMasking      | 0
# 5  | freq_mask_transform | FrequencyMasking | 0
# 6  | melspec_transform   | MelSpectrogram   | 0
# 7  | db_transform        | AmplitudeToDB    | 0
# 8  | bn0                 | BatchNorm2d      | 256
# 9  | encoder             | Sequential       | 20.2 M
# 10 | fc1                 | Linear           | 1.6 M
# 11 | att_block           | AttBlockV2       | 2.1 M
# ----------------------------------------------------------
# 24.0 M    Trainable params
# 0         Non-trainable params
# 24.0 M    Total params
# 95.817    Total estimated model params size (MB)
# Running trainer.fit
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# epoch 0 train loss 17.417347993966306
# epoch 1 train loss 16.946361193695083

# %%
# model.train()
# for batch in dl_train:
    
#     # batch[0].shape, batch[1].shape, batch[2].shape => torch.Size([16, 1, 320000]) torch.Size([16, 834]) torch.Size([16])
#     draw_graph(model, input_data = [batch], expand_nested=True, save_graph=True).visual_graph
#     break

# %% [markdown]
# ### Convert to onnx

# %%
# pip3 install openvino-dev
# !python3 convert.py --model_name sed_v2s
# Out:
# loading model from checkpoint
# Exported graph: graph(%x : Float(120, 3, 128, 768, strides=[294912, 98304, 768, 1], requires_grad=0, device=cpu),
#       %tta_delta : Long(requires_grad=0, device=cpu),
#       %bn0.weight : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %bn0.bias : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %bn0.running_mean : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %bn0.running_var : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %encoder.2.3.0.se.conv_reduce.weight : Float(16, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.0.se.conv_reduce.bias : Float(16, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.0.se.conv_expand.weight : Float(256, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.0.se.conv_expand.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.1.se.conv_reduce.weight : Float(32, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.1.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.1.se.conv_expand.weight : Float(512, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.1.se.conv_expand.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.2.se.conv_reduce.weight : Float(32, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.2.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.2.se.conv_expand.weight : Float(512, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.2.se.conv_expand.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.3.se.conv_reduce.weight : Float(32, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.3.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.3.se.conv_expand.weight : Float(512, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.3.se.conv_expand.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.4.se.conv_reduce.weight : Float(32, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.4.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.4.se.conv_expand.weight : Float(512, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.4.se.conv_expand.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.5.se.conv_reduce.weight : Float(32, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.5.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.3.5.se.conv_expand.weight : Float(512, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.3.5.se.conv_expand.bias : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.0.se.conv_reduce.weight : Float(32, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.0.se.conv_reduce.bias : Float(32, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.0.se.conv_expand.weight : Float(768, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.0.se.conv_expand.bias : Float(768, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.1.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.1.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.1.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.1.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.2.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.2.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.2.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.2.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.3.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.3.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.3.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.3.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.4.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.4.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.4.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.4.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.5.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.5.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.5.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.5.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.6.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.6.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.6.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.6.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.7.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.7.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.7.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.7.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.8.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.8.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.4.8.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.4.8.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.0.se.conv_reduce.weight : Float(40, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.0.se.conv_reduce.bias : Float(40, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.0.se.conv_expand.weight : Float(960, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.0.se.conv_expand.bias : Float(960, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.1.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.1.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.1.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.1.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.2.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.2.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.2.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.2.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.3.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.3.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.3.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.3.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.4.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.4.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.4.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.4.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.5.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.5.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.5.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.5.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.6.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.6.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.6.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.6.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.7.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.7.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.7.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.7.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.8.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.8.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.8.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.8.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.9.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.9.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.9.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.9.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.10.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.10.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.10.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.10.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.11.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.11.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.11.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.11.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.12.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.12.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.12.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.12.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.13.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.13.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.13.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.13.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.14.se.conv_reduce.weight : Float(64, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.14.se.conv_reduce.bias : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %encoder.2.5.14.se.conv_expand.weight : Float(1536, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cpu),
#       %encoder.2.5.14.se.conv_expand.bias : Float(1536, strides=[1], requires_grad=1, device=cpu),
#       %fc1.bias : Float(1280, strides=[1], requires_grad=1, device=cpu),
#       %att_block.cla.weight : Float(264, 1280, 1, strides=[1280, 1, 1], requires_grad=1, device=cpu),
#       %att_block.cla.bias : Float(264, strides=[1], requires_grad=1, device=cpu),
#       %onnx::Conv_1931 : Float(24, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1932 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1934 : Float(24, 24, 3, 3, strides=[216, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1935 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1937 : Float(24, 24, 3, 3, strides=[216, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1938 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1940 : Float(96, 24, 3, 3, strides=[216, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1941 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1943 : Float(48, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1944 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1946 : Float(192, 48, 3, 3, strides=[432, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1947 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1949 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1950 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1952 : Float(192, 48, 3, 3, strides=[432, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1953 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1955 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1956 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1958 : Float(192, 48, 3, 3, strides=[432, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1959 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1961 : Float(48, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1962 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1964 : Float(192, 48, 3, 3, strides=[432, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1965 : Float(192, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1967 : Float(64, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1968 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1970 : Float(256, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1971 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1973 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1974 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1976 : Float(256, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1977 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1979 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1980 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1982 : Float(256, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1983 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1985 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1986 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1988 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1989 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1991 : Float(256, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1992 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1994 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1995 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_1997 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_1998 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2000 : Float(512, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2001 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2003 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2004 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2006 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2007 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2009 : Float(512, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2010 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2012 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2013 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2015 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2016 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2018 : Float(512, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2019 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2021 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2022 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2024 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2025 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2027 : Float(512, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2028 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2030 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2031 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2033 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2034 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2036 : Float(512, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2037 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2039 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2040 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2042 : Float(768, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2043 : Float(768, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2045 : Float(768, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2046 : Float(768, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2048 : Float(160, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2049 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2051 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2052 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2054 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2055 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2057 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2058 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2060 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2061 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2063 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2064 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2066 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2067 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2069 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2070 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2072 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2073 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2075 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2076 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2078 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2079 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2081 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2082 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2084 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2085 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2087 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2088 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2090 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2091 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2093 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2094 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2096 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2097 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2099 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2100 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2102 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2103 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2105 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2106 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2108 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2109 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2111 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2112 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2114 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2115 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2117 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2118 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2120 : Float(160, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2121 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2123 : Float(960, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2124 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2126 : Float(960, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2127 : Float(960, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2129 : Float(256, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2130 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2132 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2133 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2135 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2136 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2138 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2139 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2141 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2142 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2144 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2145 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2147 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2148 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2150 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2151 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2153 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2154 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2156 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2157 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2159 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2160 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2162 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2163 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2165 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2166 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2168 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2169 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2171 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2172 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2174 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2175 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2177 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2178 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2180 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2181 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2183 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2184 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2186 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2187 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2189 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2190 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2192 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2193 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2195 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2196 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2198 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2199 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2201 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2202 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2204 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2205 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2207 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2208 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2210 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2211 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2213 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2214 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2216 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2217 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2219 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2220 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2222 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2223 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2225 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2226 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2228 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2229 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2231 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2232 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2234 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2235 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2237 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2238 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2240 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2241 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2243 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2244 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2246 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2247 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2249 : Float(1536, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2250 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2252 : Float(1536, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2253 : Float(1536, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2255 : Float(256, 1536, 1, 1, strides=[1536, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2256 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %onnx::Conv_2258 : Float(1280, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %onnx::Conv_2259 : Float(1280, strides=[1], requires_grad=0, device=cpu),
#       %onnx::MatMul_2293 : Float(1280, 1280, strides=[1, 1280], requires_grad=0, device=cpu)):
#   %/Transpose_output_0 : Float(120, 128, 768, 3, strides=[294912, 768, 1, 98304], requires_grad=0, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1], onnx_name="/Transpose"](%x), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:752:0
#   %/bn0/BatchNormalization_output_0 : Float(120, 128, 768, 3, strides=[294912, 2304, 3, 1], requires_grad=1, device=cpu) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002, training_mode=0, onnx_name="/bn0/BatchNormalization"](%/Transpose_output_0, %bn0.weight, %bn0.bias, %bn0.running_mean, %bn0.running_var), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.batchnorm.BatchNorm2d::bn0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/functional.py:2451:0
#   %/Transpose_1_output_0 : Float(120, 3, 128, 768, strides=[294912, 1, 2304, 3], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 3, 1, 2], onnx_name="/Transpose_1"](%/bn0/BatchNormalization_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:759:0
#   %/encoder/encoder.0/Constant_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={64}, onnx_name="/encoder/encoder.0/Constant"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Ceil_output_0 : Float(requires_grad=0, device=cpu) = onnx::Ceil[onnx_name="/encoder/encoder.0/Ceil"](%/encoder/encoder.0/Constant_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}, onnx_name="/encoder/encoder.0/Constant_1"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Sub_output_0 : Float(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/encoder/encoder.0/Sub"](%/encoder/encoder.0/Ceil_output_0, %/encoder/encoder.0/Constant_1_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_2_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/encoder/encoder.0/Constant_2"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Mul_output_0 : Float(requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/encoder/encoder.0/Mul"](%/encoder/encoder.0/Sub_output_0, %/encoder/encoder.0/Constant_2_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_3_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/encoder/encoder.0/Constant_3"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Add_output_0 : Float(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/encoder/encoder.0/Add"](%/encoder/encoder.0/Mul_output_0, %/encoder/encoder.0/Constant_3_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_4_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}, onnx_name="/encoder/encoder.0/Constant_4"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Add_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/encoder/encoder.0/Add_1"](%/encoder/encoder.0/Add_output_0, %/encoder/encoder.0/Constant_4_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_5_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={128}, onnx_name="/encoder/encoder.0/Constant_5"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Sub_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/encoder/encoder.0/Sub_1"](%/encoder/encoder.0/Add_1_output_0, %/encoder/encoder.0/Constant_5_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_6_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}, onnx_name="/encoder/encoder.0/Constant_6"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %onnx::Clip_814 : Tensor? = prim::Constant(), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Clip_output_0 : Float(requires_grad=0, device=cpu) = onnx::Clip[onnx_name="/encoder/encoder.0/Clip"](%/encoder/encoder.0/Sub_1_output_0, %/encoder/encoder.0/Constant_6_output_0, %onnx::Clip_814), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_7_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={384}, onnx_name="/encoder/encoder.0/Constant_7"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Ceil_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Ceil[onnx_name="/encoder/encoder.0/Ceil_1"](%/encoder/encoder.0/Constant_7_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_8_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}, onnx_name="/encoder/encoder.0/Constant_8"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Sub_2_output_0 : Float(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/encoder/encoder.0/Sub_2"](%/encoder/encoder.0/Ceil_1_output_0, %/encoder/encoder.0/Constant_8_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_9_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/encoder/encoder.0/Constant_9"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Mul_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/encoder/encoder.0/Mul_1"](%/encoder/encoder.0/Sub_2_output_0, %/encoder/encoder.0/Constant_9_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_10_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/encoder/encoder.0/Constant_10"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Add_2_output_0 : Float(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/encoder/encoder.0/Add_2"](%/encoder/encoder.0/Mul_1_output_0, %/encoder/encoder.0/Constant_10_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_11_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}, onnx_name="/encoder/encoder.0/Constant_11"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Add_3_output_0 : Float(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/encoder/encoder.0/Add_3"](%/encoder/encoder.0/Add_2_output_0, %/encoder/encoder.0/Constant_11_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_12_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={768}, onnx_name="/encoder/encoder.0/Constant_12"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Sub_3_output_0 : Float(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/encoder/encoder.0/Sub_3"](%/encoder/encoder.0/Add_3_output_0, %/encoder/encoder.0/Constant_12_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_13_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}, onnx_name="/encoder/encoder.0/Constant_13"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %onnx::Clip_830 : Tensor? = prim::Constant(), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Clip_1_output_0 : Float(requires_grad=0, device=cpu) = onnx::Clip[onnx_name="/encoder/encoder.0/Clip_1"](%/encoder/encoder.0/Sub_3_output_0, %/encoder/encoder.0/Constant_13_output_0, %onnx::Clip_830), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/timm/layers/padding.py:21:0
#   %/encoder/encoder.0/Constant_14_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/encoder/encoder.0/Constant_14"](), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:868:0
#   %/encoder/encoder.0/Div_output_0 : Float(device=cpu) = onnx::Div[onnx_name="/encoder/encoder.0/Div"](%/encoder/encoder.0/Clip_1_output_0, %/encoder/encoder.0/Constant_14_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:868:0
#   %/encoder/encoder.0/Cast_output_0 : Long(device=cpu) = onnx::Cast[to=7, onnx_name="/encoder/encoder.0/Cast"](%/encoder/encoder.0/Div_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.conv2d_same.Conv2dSame::encoder.0 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:868:0
# ...
#   %/encoder/encoder.4/act/Mul_output_0 : Float(*, 1280, *, *, strides=[122880, 1, 30720, 1280], requires_grad=1, device=cpu) = onnx::Mul[onnx_name="/encoder/encoder.4/act/Mul"](%/encoder/encoder.3/Conv_output_0, %/encoder/encoder.4/act/Sigmoid_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.container.Sequential::encoder/timm.layers.norm_act.BatchNormAct2d::encoder.4/torch.nn.modules.activation.SiLU::act # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/functional.py:2058:0
#   %/ReduceMean_output_0 : Float(*, 1280, *, strides=[30720, 24, 1], requires_grad=1, device=cpu) = onnx::ReduceMean[axes=[2], keepdims=0, onnx_name="/ReduceMean"](%/encoder/encoder.4/act/Mul_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:764:0
#   %/MaxPool_output_0 : Float(*, 1280, *, strides=[30720, 24, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3], pads=[1, 1], strides=[1], onnx_name="/MaxPool"](%/ReduceMean_output_0), scope: modules.model.BirdClefInferModelSED:: # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/functional.py:696:0
#   %/Constant_output_0 : Long(6, strides=[1], device=cpu) = onnx::Constant[value= 0  0  1  0  0  1 [ CPULongType{6} ], onnx_name="/Constant"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:768:0
#   %/Pad_output_0 : Float(*, 1280, *, device=cpu) = onnx::Pad[mode="constant", onnx_name="/Pad"](%/ReduceMean_output_0, %/Constant_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:768:0
#   %/AveragePool_output_0 : Float(*, 1280, *, strides=[30720, 24, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, kernel_shape=[3], pads=[0, 0], strides=[1], onnx_name="/AveragePool"](%/Pad_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:768:0
#   %/Add_output_0 : Float(*, 1280, *, strides=[30720, 24, 1], requires_grad=1, device=cpu) = onnx::Add[onnx_name="/Add"](%/MaxPool_output_0, %/AveragePool_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:769:0
#   %/Transpose_2_output_0 : Float(*, *, 1280, strides=[30720, 1, 24], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1], onnx_name="/Transpose_2"](%/Add_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:772:0
#   %/fc1/MatMul_output_0 : Float(*, *, 1280, device=cpu) = onnx::MatMul[onnx_name="/fc1/MatMul"](%/Transpose_2_output_0, %onnx::MatMul_2293), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.linear.Linear::fc1 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/modules/linear.py:114:0
#   %/fc1/Add_output_0 : Float(*, *, 1280, strides=[30720, 1280, 1], requires_grad=1, device=cpu) = onnx::Add[onnx_name="/fc1/Add"](%fc1.bias, %/fc1/MatMul_output_0), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.linear.Linear::fc1 # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/modules/linear.py:114:0
#   %/Relu_output_0 : Float(*, *, 1280, strides=[30720, 1280, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/Relu"](%/fc1/Add_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:773:0
#   %/Transpose_3_output_0 : Float(*, 1280, *, strides=[30720, 1, 1280], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1], onnx_name="/Transpose_3"](%/Relu_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:774:0
#   %/Constant_1_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}, onnx_name="/Constant_1"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_2_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={6}, onnx_name="/Constant_2"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_3_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={18}, onnx_name="/Constant_3"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_4_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}, onnx_name="/Constant_4"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Slice_output_0 : Float(*, 1280, *, strides=[30720, 1, 1280], requires_grad=1, device=cpu) = onnx::Slice[onnx_name="/Slice"](%/Transpose_3_output_0, %/Constant_2_output_0, %/Constant_3_output_0, %/Constant_1_output_0, %/Constant_4_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/cla/Conv_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1], group=1, kernel_shape=[1], pads=[0, 0], strides=[1], onnx_name="/cla/Conv"](%/Slice_output_0, %att_block.cla.weight, %att_block.cla.bias), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.conv.Conv1d::cla # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/modules/conv.py:310:0
#   %/Sigmoid_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=1, device=cpu) = onnx::Sigmoid[onnx_name="/Sigmoid"](%/cla/Conv_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:895:0
#   %/ReduceMax_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::ReduceMax[axes=[2], keepdims=0, onnx_name="/ReduceMax"](%/Sigmoid_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:896:0
#   %/Constant_5_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={6}, onnx_name="/Constant_5"](), scope: modules.model.BirdClefInferModelSED:: # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:834:0
#   %/Sub_output_0 : Long(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/Sub"](%/Constant_5_output_0, %tta_delta), scope: modules.model.BirdClefInferModelSED:: # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:834:0
#   %/Constant_6_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={18}, onnx_name="/Constant_6"](), scope: modules.model.BirdClefInferModelSED:: # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:834:0
#   %/Sub_1_output_0 : Long(requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/Sub_1"](%/Constant_6_output_0, %tta_delta), scope: modules.model.BirdClefInferModelSED:: # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/_tensor.py:834:0
#   %/Constant_7_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}, onnx_name="/Constant_7"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Unsqueeze_output_0 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[onnx_name="/Unsqueeze"](%/Sub_output_0, %/Constant_7_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_8_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}, onnx_name="/Constant_8"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Unsqueeze_1_output_0 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[onnx_name="/Unsqueeze_1"](%/Sub_1_output_0, %/Constant_8_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_9_output_0 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/Constant_9"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_10_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}, onnx_name="/Constant_10"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Slice_1_output_0 : Float(*, *, *, strides=[30720, 1, 1280], requires_grad=1, device=cpu) = onnx::Slice[onnx_name="/Slice_1"](%/Transpose_3_output_0, %/Unsqueeze_output_0, %/Unsqueeze_1_output_0, %/Constant_9_output_0, %/Constant_10_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/cla_1/Conv_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1], group=1, kernel_shape=[1], pads=[0, 0], strides=[1], onnx_name="/cla_1/Conv"](%/Slice_1_output_0, %att_block.cla.weight, %att_block.cla.bias), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.conv.Conv1d::cla # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/modules/conv.py:310:0
#   %/Sigmoid_1_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=1, device=cpu) = onnx::Sigmoid[onnx_name="/Sigmoid_1"](%/cla_1/Conv_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:895:0
#   %/ReduceMax_1_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::ReduceMax[axes=[2], keepdims=0, onnx_name="/ReduceMax_1"](%/Sigmoid_1_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:896:0
#   %/Constant_11_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={6}, onnx_name="/Constant_11"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:883:0
#   %/Add_1_output_0 : Long(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/Add_1"](%tta_delta, %/Constant_11_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:883:0
#   %/Constant_12_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={18}, onnx_name="/Constant_12"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:884:0
#   %/Add_2_output_0 : Long(requires_grad=0, device=cpu) = onnx::Add[onnx_name="/Add_2"](%tta_delta, %/Constant_12_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:884:0
#   %/Constant_13_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}, onnx_name="/Constant_13"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Unsqueeze_2_output_0 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[onnx_name="/Unsqueeze_2"](%/Add_1_output_0, %/Constant_13_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_14_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}, onnx_name="/Constant_14"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Unsqueeze_3_output_0 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[onnx_name="/Unsqueeze_3"](%/Add_2_output_0, %/Constant_14_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_15_output_0 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/Constant_15"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Constant_16_output_0 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}, onnx_name="/Constant_16"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/Slice_2_output_0 : Float(*, *, *, strides=[30720, 1, 1280], requires_grad=1, device=cpu) = onnx::Slice[onnx_name="/Slice_2"](%/Transpose_3_output_0, %/Unsqueeze_2_output_0, %/Unsqueeze_3_output_0, %/Constant_15_output_0, %/Constant_16_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:891:0
#   %/cla_2/Conv_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1], group=1, kernel_shape=[1], pads=[0, 0], strides=[1], onnx_name="/cla_2/Conv"](%/Slice_2_output_0, %att_block.cla.weight, %att_block.cla.bias), scope: modules.model.BirdClefInferModelSED::/torch.nn.modules.conv.Conv1d::cla # /home/na/miniconda3/envs/base_2/lib/python3.7/site-packages/torch/nn/modules/conv.py:310:0
#   %/Sigmoid_2_output_0 : Float(*, 264, *, strides=[3168, 12, 1], requires_grad=1, device=cpu) = onnx::Sigmoid[onnx_name="/Sigmoid_2"](%/cla_2/Conv_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:895:0
#   %/ReduceMax_2_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::ReduceMax[axes=[2], keepdims=0, onnx_name="/ReduceMax_2"](%/Sigmoid_2_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:896:0
#   %/Constant_17_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}, onnx_name="/Constant_17"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Mul_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::Mul[onnx_name="/Mul"](%/ReduceMax_output_0, %/Constant_17_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Constant_18_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.25}, onnx_name="/Constant_18"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Mul_1_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::Mul[onnx_name="/Mul_1"](%/ReduceMax_1_output_0, %/Constant_18_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Add_3_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::Add[onnx_name="/Add_3"](%/Mul_output_0, %/Mul_1_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Constant_19_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.25}, onnx_name="/Constant_19"](), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %/Mul_2_output_0 : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::Mul[onnx_name="/Mul_2"](%/ReduceMax_2_output_0, %/Constant_19_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   %y : Float(*, 264, strides=[264, 1], requires_grad=1, device=cpu) = onnx::Add[onnx_name="/Add_4"](%/Add_3_output_0, %/Mul_2_output_0), scope: modules.model.BirdClefInferModelSED:: # /media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/modules/model.py:887:0
#   return (%y)
# Exporting ONNX model to IR... This may take a few minutes.
